# %% [markdown]
# ![criacao1.png](data:image/png;base64,...)

# %% [markdown]
# ![criacao2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![criacaoVendas.PNG](data:image/png;base64,...)

# %% [markdown]
# ![idade.PNG](data:image/png;base64,...)

# %% [markdown]
# ![idadeMediaClientes.PNG](data:image/png;base64,...)

# %% [markdown]
# ![nome.PNG](data:image/png;base64,...)

# %% [markdown]
# ![ordenaPreco.PNG](data:image/png;base64,...)

# %% [markdown]
# ![totalVendas.PNG](data:image/png;base64,...)
